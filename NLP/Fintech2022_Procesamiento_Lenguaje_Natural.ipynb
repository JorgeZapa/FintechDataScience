# %%
from IPython.display import Image
from sklearn.decomposition import PCA
from matplotlib import pyplot

# %% [markdown]
# #Word embeddings

# %%
# !wget https://miro.medium.com/max/1400/1*OEmWDt4eztOcm5pr2QbxfA.png
# Out:
# ...
# --2022-01-23 19:32:00--  https://miro.medium.com/max/1400/1*OEmWDt4eztOcm5pr2QbxfA.png
# Resolving miro.medium.com (miro.medium.com)... 162.159.152.4, 162.159.153.4, 2606:4700:7::a29f:9804, ...
# Connecting to miro.medium.com (miro.medium.com)|162.159.152.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 122312 (119K) [image/png]
# Saving to: ‘1*OEmWDt4eztOcm5pr2QbxfA.png’
#
# 1*OEmWDt4eztOcm5pr2 100%[===================>] 119.45K  --.-KB/s    in 0.02s
#
# 2022-01-23 19:32:00 (7.17 MB/s) - ‘1*OEmWDt4eztOcm5pr2QbxfA.png’ saved [122312/122312]

# %%
Image("1*OEmWDt4eztOcm5pr2QbxfA.png")

# %%
# !wget https://miro.medium.com/max/1024/1*vfLvJF8wHaQjDaWv6Mab2w.png
# Out:
# ...
# --2022-01-23 19:32:00--  https://miro.medium.com/max/1024/1*vfLvJF8wHaQjDaWv6Mab2w.png
# Resolving miro.medium.com (miro.medium.com)... 162.159.152.4, 162.159.153.4, 2606:4700:7::a29f:9804, ...
# Connecting to miro.medium.com (miro.medium.com)|162.159.152.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 127337 (124K) [image/png]
# Saving to: ‘1*vfLvJF8wHaQjDaWv6Mab2w.png’
#
# 1*vfLvJF8wHaQjDaWv6 100%[===================>] 124.35K  --.-KB/s    in 0.02s
#
# 2022-01-23 19:32:00 (7.55 MB/s) - ‘1*vfLvJF8wHaQjDaWv6Mab2w.png’ saved [127337/127337]

# %%
Image("1*vfLvJF8wHaQjDaWv6Mab2w.png")

# %%
# !wget https://miro.medium.com/max/1400/1*sAJdxEsDjsPMioHyzlN3_A.png
# Out:
# ...
# --2022-01-23 19:32:01--  https://miro.medium.com/max/1400/1*sAJdxEsDjsPMioHyzlN3_A.png
# Resolving miro.medium.com (miro.medium.com)... 162.159.152.4, 162.159.153.4, 2606:4700:7::a29f:9804, ...
# Connecting to miro.medium.com (miro.medium.com)|162.159.152.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 197322 (193K) [image/png]
# Saving to: ‘1*sAJdxEsDjsPMioHyzlN3_A.png’
#
# 1*sAJdxEsDjsPMioHyz 100%[===================>] 192.70K  --.-KB/s    in 0.02s
#
# 2022-01-23 19:32:01 (11.1 MB/s) - ‘1*sAJdxEsDjsPMioHyzlN3_A.png’ saved [197322/197322]

# %%
Image("1*sAJdxEsDjsPMioHyzlN3_A.png")

# %% [markdown]
# Vemos los word embeddings que hay disponibles en esta librería:

# %%
import gensim.downloader
# Show all available models in gensim-data
print(list(gensim.downloader.info()['models'].keys()))
# Out:
# ['fasttext-wiki-news-subwords-300', 'conceptnet-numberbatch-17-06-300', 'word2vec-ruscorpora-300', 'word2vec-google-news-300', 'glove-wiki-gigaword-50', 'glove-wiki-gigaword-100', 'glove-wiki-gigaword-200', 'glove-wiki-gigaword-300', 'glove-twitter-25', 'glove-twitter-50', 'glove-twitter-100', 'glove-twitter-200', '__testing_word2vec-matrix-synopsis']

# %% [markdown]
# Descargamos los de Google News de tamaño 300:

# %%
glove_vectors = gensim.downloader.load('glove-twitter-50')
# Out:
# [==================================================] 100.0% 199.5/199.5MB downloaded

# %%
glove_vectors.most_similar('father')
# Out:
# [('mother', 0.9128072261810303),
#  ('daughter', 0.8920575976371765),
#  ('child', 0.8722296953201294),
#  ('husband', 0.8656126856803894),
#  ('wife', 0.8380875587463379),
#  ('grandpa', 0.8354905843734741),
#  ('whose', 0.8316891193389893),
#  ('dad', 0.8267687559127808),
#  ('brother', 0.8217860460281372),
#  ('grandmother', 0.8215569257736206)]

# %%
glove_vectors.most_similar('cat')
# Out:
# [('dog', 0.9429584741592407),
#  ('pet', 0.8726721405982971),
#  ('kitty', 0.8676421046257019),
#  ('bear', 0.8655619621276855),
#  ('monkey', 0.8506731390953064),
#  ('pig', 0.8369913101196289),
#  ('puppy', 0.8335512280464172),
#  ('kitten', 0.829558789730072),
#  ('cats', 0.8218453526496887),
#  ('dogs', 0.8203402757644653)]

# %%
glove_vectors.most_similar('music')
# Out:
# [('songs', 0.882312536239624),
#  ('song', 0.8741054534912109),
#  ('mix', 0.854918360710144),
#  ('listen', 0.8400319218635559),
#  ('album', 0.8385236263275146),
#  ('live', 0.8318065404891968),
#  ('tunes', 0.8280075192451477),
#  ('tune', 0.8264240026473999),
#  ('lyrics', 0.8148279190063477),
#  ('track', 0.814198911190033)]

# %%
glove_vectors.wv["france"]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.
# array([ 0.56505 ,  0.06042 , -0.54412 ,  0.25482 , -0.22366 ,  0.48537 ,
#        -0.5463  , -0.10671 ,  0.46851 ,  0.23388 ,  0.15075 , -1.4574  ,
#        -2.9231  ,  0.55787 ,  0.54811 ,  0.61497 , -0.49392 ,  0.48395 ,
#        -1.0035  ,  0.27119 ,  1.3026  , -1.5639  ,  0.26662 , -1.4163  ,
#         0.47508 , -0.077258, -0.084553,  0.55242 , -0.25179 , -0.30683 ,
#         0.2789  , -1.1061  , -0.88122 , -0.28746 ,  1.6772  ,  0.012812,
#         0.044802, -0.14176 ,  0.5557  ,  0.31483 , -0.37103 , -1.2528  ,
#        -0.43005 ,  1.3489  ,  0.015843, -0.49958 , -0.18774 , -0.070059,
#         0.96352 , -0.66579 ], dtype=float32)

# %%
#Visualizing data
words = ["france", "germany", "india", "truck", "boat", "car", "teacher", "student", "man", "woman", "cat", "dog"]
 
X = glove_vectors.wv[words]
pca = PCA(n_components=2)
result = pca.fit_transform(X)
 
pyplot.scatter(result[:, 0], result[:, 1])
for i, word in enumerate(words):
    pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   after removing the cwd from sys.path.

# %% [markdown]
# Hugging Face
# ====

# %% [markdown]
# Referencia: https://huggingface.co/course/chapter1/3?fw=pt

# %% [markdown]
# La librería de `transformers` es una librería de NLP (Natural Language Processing) desde la que se pueden descargar y usar modelos de NLP ya entrenados.

# %%
# !pip install datasets transformers[sentencepiece]
# Out:
# ...
#      |████████████████████████████████| 311 kB 7.3 MB/s
# ...
#      |████████████████████████████████| 3.4 MB 75.1 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 25.5 MB/s
# ...
#      |████████████████████████████████| 243 kB 83.9 MB/s
# ...
#      |████████████████████████████████| 133 kB 79.9 MB/s
# ...
#      |████████████████████████████████| 67 kB 6.0 MB/s
# ...
#      |████████████████████████████████| 144 kB 86.2 MB/s
# ...
#      |████████████████████████████████| 271 kB 75.1 MB/s
# ...
#      |████████████████████████████████| 94 kB 4.4 MB/s
# ...
#      |████████████████████████████████| 596 kB 80.2 MB/s
# ...
#      |████████████████████████████████| 895 kB 68.2 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 23.2 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 73.5 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
from transformers import pipeline

# %% [markdown]
# ##Sentiment analysis

# %%
# !wget https://www.kdnuggets.com/images/sentiment-fig-1-689.jpg
# Out:
# --2022-01-23 19:34:43--  https://www.kdnuggets.com/images/sentiment-fig-1-689.jpg
# Resolving www.kdnuggets.com (www.kdnuggets.com)... 104.26.2.64, 104.26.3.64, 172.67.68.178, ...
# Connecting to www.kdnuggets.com (www.kdnuggets.com)|104.26.2.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46043 (45K) [image/jpeg]
# Saving to: ‘sentiment-fig-1-689.jpg’
#
# sentiment-fig-1-689 100%[===================>]  44.96K  --.-KB/s    in 0s
#
# 2022-01-23 19:34:43 (127 MB/s) - ‘sentiment-fig-1-689.jpg’ saved [46043/46043]

# %%
Image("sentiment-fig-1-689.jpg")

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
  
tokenizer = AutoTokenizer.from_pretrained("finiteautomata/beto-sentiment-analysis")
model = AutoModelForSequenceClassification.from_pretrained("finiteautomata/beto-sentiment-analysis")

classifier = pipeline("sentiment-analysis",  model = model, tokenizer = tokenizer)
# Out:
# Downloading:   0%|          | 0.00/528 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/841 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/236k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/469k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/67.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/419M [00:00<?, ?B/s]

# %%
classifier(
    ["Me gusta mucho el chocolate.", "Esta clase es un rollo.", "Este producto es malísimo.", "Me lo he pasado genial hoy en la discoteca."]
)
# Out:
# [{'label': 'POS', 'score': 0.9985623955726624},
#  {'label': 'NEG', 'score': 0.999342143535614},
#  {'label': 'NEG', 'score': 0.9988352656364441},
#  {'label': 'POS', 'score': 0.9985080361366272}]

# %% [markdown]
# ##Zero-shot classification

# %%
# !wget https://media.springernature.com/original/springer-static/image/chp%3A10.1007%2F978-3-030-04167-0_4/MediaObjects/476530_1_En_4_Fig1_HTML.png
# Out:
# --2022-01-23 19:35:01--  https://media.springernature.com/original/springer-static/image/chp%3A10.1007%2F978-3-030-04167-0_4/MediaObjects/476530_1_En_4_Fig1_HTML.png
# Resolving media.springernature.com (media.springernature.com)... 151.101.0.95, 151.101.64.95, 151.101.128.95, ...
# Connecting to media.springernature.com (media.springernature.com)|151.101.0.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/png]
# Saving to: ‘476530_1_En_4_Fig1_HTML.png’
#
# 476530_1_En_4_Fig1_     [   <=>              ] 602.51K  1.16MB/s    in 0.5s
#
# 2022-01-23 19:35:02 (1.16 MB/s) - ‘476530_1_En_4_Fig1_HTML.png’ saved [616973]

# %%
Image("476530_1_En_4_Fig1_HTML.png")

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("Recognai/bert-base-spanish-wwm-cased-xnli")
model = AutoModelForSequenceClassification.from_pretrained("Recognai/bert-base-spanish-wwm-cased-xnli")

classifier = pipeline("zero-shot-classification",  model = model, tokenizer = tokenizer)
# Out:
# Downloading:   0%|          | 0.00/528 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/834 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/236k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/419M [00:00<?, ?B/s]

# %%
classifier(
    ["Mis asignaturas favoritas son matemáticas y física.", "Él votó al partido que ganó en las pasadas elecciones.", "Sé tocar la flauta, pero el piano se me da fatal.", "Me gusta el fútbol, aunque también hago natación.", "En mi tiempo libre salgo con amigos y veo películas."],
    candidate_labels=["educación", "política", "ocio", "deportes", "música"],
)
# Out:
# [{'labels': ['educación', 'ocio', 'música', 'deportes', 'política'],
#   'scores': [0.726973295211792,
#    0.08801499754190445,
#    0.0738275945186615,
#    0.06396650522947311,
#    0.04721760004758835],
#   'sequence': 'Mis asignaturas favoritas son matemáticas y física.'},
#  {'labels': ['política', 'ocio', 'música', 'educación', 'deportes'],
#   'scores': [0.61359041929245,
#    0.11499840766191483,
#    0.10138268768787384,
#    0.0939815491437912,
#    0.076046884059906],
#   'sequence': 'Él votó al partido que ganó en las pasadas elecciones.'},
#  {'labels': ['música', 'educación', 'ocio', 'política', 'deportes'],
#   'scores': [0.5246932506561279,
#    0.23448476195335388,
#    0.20399022102355957,
#    0.018853671848773956,
#    0.017978103831410408],
#   'sequence': 'Sé tocar la flauta, pero el piano se me da fatal.'},
#  {'labels': ['deportes', 'educación', 'ocio', 'música', 'política'],
#   'scores': [0.9640442728996277,
#    0.014972961507737637,
# ...

# %% [markdown]
# ##Text generation

# %%
# !wget https://iq.opengenus.org/content/images/2019/12/1_XvUt5wDQA8D3C0wAuxAvbA.png
# Out:
# --2022-01-23 19:35:22--  https://iq.opengenus.org/content/images/2019/12/1_XvUt5wDQA8D3C0wAuxAvbA.png
# Resolving iq.opengenus.org (iq.opengenus.org)... 159.89.134.55
# Connecting to iq.opengenus.org (iq.opengenus.org)|159.89.134.55|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 81131 (79K) [image/png]
# Saving to: ‘1_XvUt5wDQA8D3C0wAuxAvbA.png’
#
# 1_XvUt5wDQA8D3C0wAu 100%[===================>]  79.23K  --.-KB/s    in 0.02s
#
# 2022-01-23 19:35:22 (4.77 MB/s) - ‘1_XvUt5wDQA8D3C0wAuxAvbA.png’ saved [81131/81131]

# %%
Image("1_XvUt5wDQA8D3C0wAuxAvbA.png")

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
tokenizer = AutoTokenizer.from_pretrained("datificate/gpt2-small-spanish")
model = AutoModelForCausalLM.from_pretrained("datificate/gpt2-small-spanish")

generator = pipeline("text-generation",  model = model, tokenizer = tokenizer)
# Out:
# Downloading:   0%|          | 0.00/620 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/817 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/830k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/496k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/387 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/487M [00:00<?, ?B/s]

# %%
generator("Era un día de abril. Ella estaba a punto de")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'Era un día de abril. Ella estaba a punto de morir a la edad de 40 años, poco después del accidente, ella estaba haciendo lo que ella había deseado y ella fue, y ella sabe todo y es por ello que siempre quiso hacerlo el trabajo'}]

# %%
generator(
    "Era un día de abril. Ella estaba a punto de",
    max_length=30,
    num_return_sequences=5,
)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'Era un día de abril. Ella estaba a punto de realizar las primeras pruebas, pero su hijo que se había mudado por un accidente automovilístico acabó por'},
#  {'generated_text': 'Era un día de abril. Ella estaba a punto de terminar sus estudios en la Universidad de Illinois, de donde terminó para estudiar Derecho. Ella tenía un'},
#  {'generated_text': 'Era un día de abril. Ella estaba a punto de ir caminando y luego fue criticada por su aparente falta de seriedad y el hecho de que las calles'},
#  {'generated_text': 'Era un día de abril. Ella estaba a punto de ser llevada a Londres durante dos semanas, a pesar de que fue violada por la policía.'},
#  {'generated_text': 'Era un día de abril. Ella estaba a punto de volver a casa desde su trabajo. \n\nEl 21 de abril, la Universidad Estatal de Ohio'}]

# %% [markdown]
# ##Fill-mask

# %%
# !wget https://www.machinecurve.com/wp-content/uploads/2021/03/mlm-1024x447.png
# Out:
# --2022-01-23 19:35:50--  https://www.machinecurve.com/wp-content/uploads/2021/03/mlm-1024x447.png
# Resolving www.machinecurve.com (www.machinecurve.com)... 104.21.82.9, 172.67.167.133, 2606:4700:3035::6815:5209, ...
# Connecting to www.machinecurve.com (www.machinecurve.com)|104.21.82.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/png]
# Saving to: ‘mlm-1024x447.png’
#
# mlm-1024x447.png        [ <=>                ]  52.23K  --.-KB/s    in 0.03s
#
# 2022-01-23 19:35:51 (1.91 MB/s) - ‘mlm-1024x447.png’ saved [53481]

# %%
Image("mlm-1024x447.png")

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM

tokenizer = AutoTokenizer.from_pretrained("dccuchile/bert-base-spanish-wwm-cased")
model = AutoModelForMaskedLM.from_pretrained("dccuchile/bert-base-spanish-wwm-cased")

unmasker = pipeline("fill-mask",  model = model, tokenizer = tokenizer)
# Out:
# Downloading:   0%|          | 0.00/364 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/648 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/236k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/469k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/134 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/419M [00:00<?, ?B/s]

# %%
unmasker("En este curso habéis aprendido a [MASK] desde el principio.", top_k=2)
# Out:
# [{'score': 0.07200973480939865,
#   'sequence': 'En este curso habéis aprendido a leer desde el principio.',
#   'token': 6035,
#   'token_str': 'leer'},
#  {'score': 0.04701787978410721,
#   'sequence': 'En este curso habéis aprendido a hablar desde el principio.',
#   'token': 2125,
#   'token_str': 'hablar'}]

# %% [markdown]
# ##Named Entity Recognition

# %%
# !wget https://editor.analyticsvidhya.com/uploads/19617Intro%20image.jpg
# Out:
# --2022-01-23 19:36:08--  https://editor.analyticsvidhya.com/uploads/19617Intro%20image.jpg
# Resolving editor.analyticsvidhya.com (editor.analyticsvidhya.com)... 104.22.54.101, 172.67.38.119, 104.22.55.101, ...
# Connecting to editor.analyticsvidhya.com (editor.analyticsvidhya.com)|104.22.54.101|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66329 (65K) [image/jpeg]
# Saving to: ‘19617Intro image.jpg’
#
# 19617Intro image.jp 100%[===================>]  64.77K   259KB/s    in 0.3s
#
# 2022-01-23 19:36:10 (259 KB/s) - ‘19617Intro image.jpg’ saved [66329/66329]

# %%
Image("19617Intro image.jpg")

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification

tokenizer = AutoTokenizer.from_pretrained("mrm8488/TinyBERT-spanish-uncased-finetuned-ner")
model = AutoModelForTokenClassification.from_pretrained("mrm8488/TinyBERT-spanish-uncased-finetuned-ner")

ner = pipeline("ner", grouped_entities=True,  model = model, tokenizer = tokenizer)
# Out:
# Downloading:   0%|          | 0.00/136 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/896 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/242k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/55.3M [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/pipelines/token_classification.py:136: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="AggregationStrategy.SIMPLE"` instead.
#   f'`grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="{aggregation_strategy}"` instead.'

# %%
from transformers import pipeline

ner("Me llamo Laura, tengo 33 años y trabajo en Madrid.")
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# [{'end': 14,
#   'entity_group': 'PER',
#   'score': 0.9227996,
#   'start': 9,
#   'word': 'Laura'},
#  {'end': 49,
#   'entity_group': 'LOC',
#   'score': 0.9518505,
#   'start': 43,
#   'word': 'Madrid'}]

# %% [markdown]
# ##Question answering

# %%
# !wget https://production-media.paperswithcode.com/tasks/question.png
# Out:
# --2022-01-23 19:36:19--  https://production-media.paperswithcode.com/tasks/question.png
# Resolving production-media.paperswithcode.com (production-media.paperswithcode.com)... 104.26.12.155, 104.26.13.155, 172.67.73.69, ...
# Connecting to production-media.paperswithcode.com (production-media.paperswithcode.com)|104.26.12.155|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 106477 (104K) [image/png]
# Saving to: ‘question.png’
#
# question.png        100%[===================>] 103.98K  --.-KB/s    in 0.07s
#
# 2022-01-23 19:36:19 (1.39 MB/s) - ‘question.png’ saved [106477/106477]

# %%
Image("question.png")

# %%
from transformers import AutoTokenizer, AutoModelForQuestionAnswering

tokenizer = AutoTokenizer.from_pretrained("mrm8488/bert-base-spanish-wwm-cased-finetuned-spa-squad2-es")
model = AutoModelForQuestionAnswering.from_pretrained("mrm8488/bert-base-spanish-wwm-cased-finetuned-spa-squad2-es")

question_answerer = pipeline("question-answering",  model = model, tokenizer = tokenizer)
# Out:
# Downloading:   0%|          | 0.00/135 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/465 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/237k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/419M [00:00<?, ?B/s]

# %%
question_answerer(
    question="¿Dónde trabajo?",
    context="Me llamo Laura, tengo 33 años y trabajo en Madrid.",
)
# Out:
# {'answer': 'Madrid', 'end': 49, 'score': 0.9127203226089478, 'start': 43}

# %%
question_answerer(
    question="¿Cuántos años tengo?",
    context="Me llamo Laura, tengo 33 años y trabajo en Madrid.",
)
# Out:
# {'answer': '33', 'end': 24, 'score': 0.7957060933113098, 'start': 22}

# %%
question_answerer(
    question="¿Cómo me llamo?",
    context="Me llamo Laura, tengo 33 años y trabajo en Madrid.",
)
# Out:
# {'answer': 'Laura', 'end': 14, 'score': 0.9583200216293335, 'start': 9}

# %% [markdown]
# ##Summarization

# %%
# !wget https://www.scrapehero.com/wp/wp-content/uploads/2021/05/Text-Summarization-NLP.jpg
# Out:
# --2022-01-23 19:36:50--  https://www.scrapehero.com/wp/wp-content/uploads/2021/05/Text-Summarization-NLP.jpg
# Resolving www.scrapehero.com (www.scrapehero.com)... 159.89.216.6
# Connecting to www.scrapehero.com (www.scrapehero.com)|159.89.216.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89290 (87K) [image/jpeg]
# Saving to: ‘Text-Summarization-NLP.jpg’
#
# Text-Summarization- 100%[===================>]  87.20K  --.-KB/s    in 0.07s
#
# 2022-01-23 19:36:51 (1.28 MB/s) - ‘Text-Summarization-NLP.jpg’ saved [89290/89290]

# %%
Image("Text-Summarization-NLP.jpg")

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("mrm8488/bert2bert_shared-spanish-finetuned-summarization")
model = AutoModelForSeq2SeqLM.from_pretrained("mrm8488/bert2bert_shared-spanish-finetuned-summarization")

summarizer = pipeline("summarization",  model = model, tokenizer = tokenizer, min_length=30, max_length=60)
# Out:
# Downloading:   0%|          | 0.00/520 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.40k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/236k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/530M [00:00<?, ?B/s]
# The following encoder weights were not tied to the decoder ['bert/pooler']
# The following encoder weights were not tied to the decoder ['bert/pooler']

# %%
from transformers import pipeline

summarizer(
    """
Todos los vagos del universo sabemos que una de las elaboraciones más socorridas cuando tienes invitados y 
has prometido darles de comer o cenar es una tabla de embutidos y/o quesos (seguida muy de cerca por la fondue). 
Quedas como un señor o señora con escaso esfuerzo, simplemente aprendiendo a combinar estos riquísimos alimentos; 
cosa que en nuestro país -que no nos pese decirlo-, es bien sencillo, porque el producto de que disponemos es la pera y es difícil pifiarla.

Otro tema es que sea un producto que no conozcamos, y por eso pensemos que es una magnífica idea poner un cheddar o 
un parmesano mediocre en una tabla en lugar del magnífico queso artesano del pueblo de al lado, del que no has tenido noticia en tu vida. 
Espabila, alma de cántaro. De modo que no os vamos a sugerir que pongáis prosciutto del bueno en vuestra tabla, 
aunque no tengamos nada contra él: este artículo va de usar producto nacional, que además de ser bueno y abundantísimo, es de proximidad.
"""
)
# Out:
# [{'summary_text': 'En nuestro país sabemos que una de las elaboraciones más socorridas cuando tienes invitados y has prometido darles de comer o cenar es una tabla de embutidos'}]

# %% [markdown]
# ##Translation

# %%
# !wget https://cdn.analyticsvidhya.com/wp-content/uploads/2019/01/enc_dec_simple.png
# Out:
# --2022-01-23 19:37:30--  https://cdn.analyticsvidhya.com/wp-content/uploads/2019/01/enc_dec_simple.png
# Resolving cdn.analyticsvidhya.com (cdn.analyticsvidhya.com)... 172.67.38.119, 104.22.55.101, 104.22.54.101, ...
# Connecting to cdn.analyticsvidhya.com (cdn.analyticsvidhya.com)|172.67.38.119|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19474 (19K) [image/png]
# Saving to: ‘enc_dec_simple.png’
#
# enc_dec_simple.png  100%[===================>]  19.02K  --.-KB/s    in 0s
#
# 2022-01-23 19:37:31 (98.2 MB/s) - ‘enc_dec_simple.png’ saved [19474/19474]

# %%
Image("enc_dec_simple.png")

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-es")
model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-en-es")
translator = pipeline("translation", model = model, tokenizer = tokenizer)
# Out:
# Downloading:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.31k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/783k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/807k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.52M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/298M [00:00<?, ?B/s]

# %%
translator("I love going to the cinema and eating chocolate. Do you also like that?")
# Out:
# [{'translation_text': 'Me encanta ir al cine y comer chocolate. ¿También te gusta eso?'}]
