# %%
from IPython.display import Image
from sklearn.decomposition import PCA
from matplotlib import pyplot

# %% [markdown]
# #Word embeddings

# %%
# !wget https://miro.medium.com/v2/resize:fit:1100/format:webp/1*SYiW1MUZul1NvL1kc1RxwQ.png
# Out:
# Warning: wildcards not supported in HTTP.
# --2023-07-09 20:38:23--  https://miro.medium.com/v2/resize:fit:1100/format:webp/1*SYiW1MUZul1NvL1kc1RxwQ.png
# Resolving miro.medium.com (miro.medium.com)... 162.159.152.4, 162.159.153.4, 2606:4700:7::a29f:9904, ...
# Connecting to miro.medium.com (miro.medium.com)|162.159.152.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22218 (22K) [image/webp]
# Saving to: ‘1*SYiW1MUZul1NvL1kc1RxwQ.png.1’
#
# 1*SYiW1MUZul1NvL1kc 100%[===================>]  21.70K  --.-KB/s    in 0.001s
#
# 2023-07-09 20:38:24 (36.8 MB/s) - ‘1*SYiW1MUZul1NvL1kc1RxwQ.png.1’ saved [22218/22218]

# %%
Image("1*SYiW1MUZul1NvL1kc1RxwQ.png")

# %%
# !wget https://miro.medium.com/max/1024/1*vfLvJF8wHaQjDaWv6Mab2w.png
# Out:
# Warning: wildcards not supported in HTTP.
# --2023-07-09 20:38:24--  https://miro.medium.com/max/1024/1*vfLvJF8wHaQjDaWv6Mab2w.png
# Resolving miro.medium.com (miro.medium.com)... 162.159.152.4, 162.159.153.4, 2606:4700:7::a29f:9904, ...
# Connecting to miro.medium.com (miro.medium.com)|162.159.152.4|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /v2/resize:fit:1024/1*vfLvJF8wHaQjDaWv6Mab2w.png [following]
# Warning: wildcards not supported in HTTP.
# --2023-07-09 20:38:24--  https://miro.medium.com/v2/resize:fit:1024/1*vfLvJF8wHaQjDaWv6Mab2w.png
# Reusing existing connection to miro.medium.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 144748 (141K) [image/png]
# Saving to: ‘1*vfLvJF8wHaQjDaWv6Mab2w.png.6’
#
# 1*vfLvJF8wHaQjDaWv6 100%[===================>] 141.36K  --.-KB/s    in 0.02s
#
# 2023-07-09 20:38:24 (8.41 MB/s) - ‘1*vfLvJF8wHaQjDaWv6Mab2w.png.6’ saved [144748/144748]

# %%
Image("1*vfLvJF8wHaQjDaWv6Mab2w.png")

# %%
# !wget https://miro.medium.com/max/1400/1*sAJdxEsDjsPMioHyzlN3_A.png
# Out:
# Warning: wildcards not supported in HTTP.
# --2023-07-09 20:38:24--  https://miro.medium.com/max/1400/1*sAJdxEsDjsPMioHyzlN3_A.png
# Resolving miro.medium.com (miro.medium.com)... 162.159.152.4, 162.159.153.4, 2606:4700:7::a29f:9904, ...
# Connecting to miro.medium.com (miro.medium.com)|162.159.152.4|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /v2/resize:fit:1400/1*sAJdxEsDjsPMioHyzlN3_A.png [following]
# Warning: wildcards not supported in HTTP.
# --2023-07-09 20:38:24--  https://miro.medium.com/v2/resize:fit:1400/1*sAJdxEsDjsPMioHyzlN3_A.png
# Reusing existing connection to miro.medium.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 101920 (100K) [image/png]
# Saving to: ‘1*sAJdxEsDjsPMioHyzlN3_A.png.6’
#
# 1*sAJdxEsDjsPMioHyz 100%[===================>]  99.53K  --.-KB/s    in 0.01s
#
# 2023-07-09 20:38:24 (9.75 MB/s) - ‘1*sAJdxEsDjsPMioHyzlN3_A.png.6’ saved [101920/101920]

# %%
Image("1*sAJdxEsDjsPMioHyzlN3_A.png")

# %% [markdown]
# Vemos los word embeddings que hay disponibles en esta librería:

# %%
import gensim.downloader
# Show all available models in gensim-data
print(list(gensim.downloader.info()['models'].keys()))
# Out:
# ['fasttext-wiki-news-subwords-300', 'conceptnet-numberbatch-17-06-300', 'word2vec-ruscorpora-300', 'word2vec-google-news-300', 'glove-wiki-gigaword-50', 'glove-wiki-gigaword-100', 'glove-wiki-gigaword-200', 'glove-wiki-gigaword-300', 'glove-twitter-25', 'glove-twitter-50', 'glove-twitter-100', 'glove-twitter-200', '__testing_word2vec-matrix-synopsis']

# %% [markdown]
# Descargamos los de Google News de tamaño 300:

# %%
glove_vectors = gensim.downloader.load('glove-twitter-50')

# %%
glove_vectors.most_similar('father')
# Out:
# [('mother', 0.9128071069717407),
#  ('daughter', 0.8920576572418213),
#  ('child', 0.8722296357154846),
#  ('husband', 0.8656127452850342),
#  ('wife', 0.8380875587463379),
#  ('grandpa', 0.8354905247688293),
#  ('whose', 0.8316890001296997),
#  ('dad', 0.8267687559127808),
#  ('brother', 0.8217859864234924),
#  ('grandmother', 0.8215569257736206)]

# %%
glove_vectors.most_similar('cat')
# Out:
# [('dog', 0.9429584741592407),
#  ('pet', 0.8726722002029419),
#  ('kitty', 0.8676421046257019),
#  ('bear', 0.8655619025230408),
#  ('monkey', 0.8506731390953064),
#  ('pig', 0.8369912505149841),
#  ('puppy', 0.8335511684417725),
#  ('kitten', 0.829558789730072),
#  ('cats', 0.8218452334403992),
#  ('dogs', 0.8203402161598206)]

# %%
glove_vectors.most_similar('music')
# Out:
# [('songs', 0.8823125958442688),
#  ('song', 0.8741054534912109),
#  ('mix', 0.854918360710144),
#  ('listen', 0.8400319218635559),
#  ('album', 0.8385236263275146),
#  ('live', 0.8318064212799072),
#  ('tunes', 0.8280075788497925),
#  ('tune', 0.8264240622520447),
#  ('lyrics', 0.8148279190063477),
#  ('track', 0.8141987919807434)]

# %% [markdown]
# Hugging Face
# ====

# %% [markdown]
# Referencia: https://huggingface.co/course/chapter1/3?fw=pt

# %% [markdown]
# La librería de `transformers` es una librería de NLP (Natural Language Processing) desde la que se pueden descargar y usar modelos de NLP ya entrenados.

# %%
# !pip install datasets transformers[sentencepiece]
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.13.1)
# Requirement already satisfied: transformers[sentencepiece] in /usr/local/lib/python3.10/dist-packages (4.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.27.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.65.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.16.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (3.12.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.3.1)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.1.99)
# Requirement already satisfied: protobuf<=3.20.3 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (3.20.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.6.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)

# %%
from transformers import pipeline

# %% [markdown]
# ##Sentiment analysis

# %%
# !wget https://www.kdnuggets.com/images/sentiment-fig-1-689.jpg
# Out:
# --2023-07-09 20:39:39--  https://www.kdnuggets.com/images/sentiment-fig-1-689.jpg
# Resolving www.kdnuggets.com (www.kdnuggets.com)... 104.26.3.64, 172.67.68.178, 104.26.2.64, ...
# Connecting to www.kdnuggets.com (www.kdnuggets.com)|104.26.3.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48926 (48K) [image/jpeg]
# Saving to: ‘sentiment-fig-1-689.jpg.2’
#
# sentiment-fig-1-689 100%[===================>]  47.78K  --.-KB/s    in 0.006s
#
# 2023-07-09 20:39:39 (7.88 MB/s) - ‘sentiment-fig-1-689.jpg.2’ saved [48926/48926]

# %%
Image("sentiment-fig-1-689.jpg")

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("finiteautomata/beto-sentiment-analysis")
model = AutoModelForSequenceClassification.from_pretrained("finiteautomata/beto-sentiment-analysis")

classifier = pipeline("sentiment-analysis",  model = model, tokenizer = tokenizer)
# Out:
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %%
classifier(
    ["Me gusta mucho el chocolate.", "Esta clase es un rollo.", "Este producto es malísimo.", "Me lo he pasado genial hoy en la discoteca."]
)
# Out:
# [{'label': 'POS', 'score': 0.9985623955726624},
#  {'label': 'NEG', 'score': 0.999342143535614},
#  {'label': 'NEG', 'score': 0.9988352656364441},
#  {'label': 'POS', 'score': 0.9985080361366272}]

# %% [markdown]
# ##Zero-shot classification

# %%
# !wget https://media.springernature.com/original/springer-static/image/chp%3A10.1007%2F978-3-030-04167-0_4/MediaObjects/476530_1_En_4_Fig1_HTML.png
# Out:
# --2023-07-09 20:39:44--  https://media.springernature.com/original/springer-static/image/chp%3A10.1007%2F978-3-030-04167-0_4/MediaObjects/476530_1_En_4_Fig1_HTML.png
# Resolving media.springernature.com (media.springernature.com)... 151.101.0.95, 151.101.64.95, 151.101.128.95, ...
# Connecting to media.springernature.com (media.springernature.com)|151.101.0.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 616973 (603K) [image/png]
# Saving to: ‘476530_1_En_4_Fig1_HTML.png.1’
#
# 476530_1_En_4_Fig1_ 100%[===================>] 602.51K  --.-KB/s    in 0.03s
#
# 2023-07-09 20:39:44 (20.2 MB/s) - ‘476530_1_En_4_Fig1_HTML.png.1’ saved [616973/616973]

# %%
Image("476530_1_En_4_Fig1_HTML.png")

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("Recognai/bert-base-spanish-wwm-cased-xnli")
model = AutoModelForSequenceClassification.from_pretrained("Recognai/bert-base-spanish-wwm-cased-xnli")

classifier = pipeline("zero-shot-classification",  model = model, tokenizer = tokenizer)

# %%
classifier(
    ["Mis asignaturas favoritas son matemáticas y física.", "Él votó al partido que ganó en las pasadas elecciones.", "Sé tocar la flauta, pero el piano se me da fatal.", "Me gusta el fútbol, aunque también hago natación.", "En mi tiempo libre salgo con amigos y veo películas."],
    candidate_labels=["educación", "política", "ocio", "deportes", "música"],
)
# Out:
# [{'sequence': 'Mis asignaturas favoritas son matemáticas y física.',
#   'labels': ['educación', 'ocio', 'música', 'deportes', 'política'],
#   'scores': [0.7269739508628845,
#    0.08801481127738953,
#    0.07382744550704956,
#    0.0639663115143776,
#    0.04721749201416969]},
#  {'sequence': 'Él votó al partido que ganó en las pasadas elecciones.',
#   'labels': ['política', 'ocio', 'música', 'educación', 'deportes'],
#   'scores': [0.6135901212692261,
#    0.11499844491481781,
#    0.1013827994465828,
#    0.09398166835308075,
#    0.07604700326919556]},
#  {'sequence': 'Sé tocar la flauta, pero el piano se me da fatal.',
#   'labels': ['música', 'educación', 'ocio', 'política', 'deportes'],
#   'scores': [0.5246928930282593,
#    0.23448486626148224,
#    0.20399047434329987,
#    0.018853679299354553,
#    0.017978111281991005]},
#  {'sequence': 'Me gusta el fútbol, aunque también hago natación.',
#   'labels': ['deportes', 'educación', 'ocio', 'música', 'política'],
#   'scores': [0.9640443921089172,
#    0.014972959645092487,
#    0.008561620488762856,
#    0.008256920613348484,
#    0.004164152313023806]},
#  {'sequence': 'En mi tiempo libre salgo con amigos y veo películas.',
#   'labels': ['ocio', 'educación', 'política', 'música', 'deportes'],
#   'scores': [0.49952977895736694,
#    0.21135146915912628,
#    0.12326062470674515,
#    0.09089604765176773,
#    0.07496210932731628]}]

# %% [markdown]
# ##Text generation

# %%
# !wget https://iq.opengenus.org/content/images/2019/12/1_XvUt5wDQA8D3C0wAuxAvbA.png
# Out:
# --2023-07-09 20:39:53--  https://iq.opengenus.org/content/images/2019/12/1_XvUt5wDQA8D3C0wAuxAvbA.png
# Resolving iq.opengenus.org (iq.opengenus.org)... 159.89.134.55
# Connecting to iq.opengenus.org (iq.opengenus.org)|159.89.134.55|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 81131 (79K) [image/png]
# Saving to: ‘1_XvUt5wDQA8D3C0wAuxAvbA.png.1’
#
# 1_XvUt5wDQA8D3C0wAu 100%[===================>]  79.23K  --.-KB/s    in 0.02s
#
# 2023-07-09 20:39:54 (4.39 MB/s) - ‘1_XvUt5wDQA8D3C0wAuxAvbA.png.1’ saved [81131/81131]

# %%
Image("1_XvUt5wDQA8D3C0wAuxAvbA.png")

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
tokenizer = AutoTokenizer.from_pretrained("datificate/gpt2-small-spanish")
model = AutoModelForCausalLM.from_pretrained("datificate/gpt2-small-spanish")

generator = pipeline("text-generation",  model = model, tokenizer = tokenizer)

# %%
generator("Era un día de abril. Ella estaba a punto de")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1353: UserWarning: Using `max_length`'s default (50) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# [{'generated_text': 'Era un día de abril. Ella estaba a punto de dar su asistencia a los residentes, pero su plan ha arruinado la vida de los ancianos.\n\nAl igual que los otros niños, que habían decidido quedarse allí, ella y otros niños regresaron'}]

# %%
generator(
    "Era un día de abril. Ella estaba a punto de",
    max_length=30,
    num_return_sequences=5,
)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'Era un día de abril. Ella estaba a punto de convertirse en una popular cantante de éxito con su grupo de chicas, "Thankay",'},
#  {'generated_text': 'Era un día de abril. Ella estaba a punto de ser llamada a los estudios en la escuela secundaria, para ayudar en su trabajo. El director local'},
#  {'generated_text': 'Era un día de abril. Ella estaba a punto de empezar una fiesta de cumpleaños y tuvo que permanecer por mucho tiempo. A esa tarde una chica que'},
#  {'generated_text': 'Era un día de abril. Ella estaba a punto de perder el control de la compañía de producción, y sus compañeros. Poco después, la unidad de'},
#  {'generated_text': 'Era un día de abril. Ella estaba a punto de hacer un viaje a California y el 18 de abril viajó a Texas, donde asistió a una recepción'}]

# %% [markdown]
# ##Named Entity Recognition

# %%
# !wget https://editor.analyticsvidhya.com/uploads/19617Intro%20image.jpg
# Out:
# --2023-07-09 20:45:49--  https://editor.analyticsvidhya.com/uploads/19617Intro%20image.jpg
# Resolving editor.analyticsvidhya.com (editor.analyticsvidhya.com)... 172.67.74.218, 104.26.7.19, 104.26.6.19, ...
# Connecting to editor.analyticsvidhya.com (editor.analyticsvidhya.com)|172.67.74.218|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66329 (65K) [image/jpeg]
# Saving to: ‘19617Intro image.jpg’
#
# 19617Intro image.jp 100%[===================>]  64.77K   128KB/s    in 0.5s
#
# 2023-07-09 20:45:50 (128 KB/s) - ‘19617Intro image.jpg’ saved [66329/66329]

# %%
Image("19617Intro image.jpg")

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification

tokenizer = AutoTokenizer.from_pretrained("mrm8488/TinyBERT-spanish-uncased-finetuned-ner")
model = AutoModelForTokenClassification.from_pretrained("mrm8488/TinyBERT-spanish-uncased-finetuned-ner")

ner = pipeline("ner", grouped_entities=True,  model = model, tokenizer = tokenizer)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/136 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/896 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/58.0M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/token_classification.py:169: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(

# %%
from transformers import pipeline

ner("Me llamo Laura, tengo 33 años y trabajo en Madrid.")
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# [{'entity_group': 'PER',
#   'score': 0.92279965,
#   'word': 'Laura',
#   'start': 9,
#   'end': 14},
#  {'entity_group': 'LOC',
#   'score': 0.9518505,
#   'word': 'Madrid',
#   'start': 43,
#   'end': 49}]

# %% [markdown]
# ##Question answering

# %%
# !wget https://production-media.paperswithcode.com/tasks/question.png
# Out:
# --2023-07-09 20:45:55--  https://production-media.paperswithcode.com/tasks/question.png
# Resolving production-media.paperswithcode.com (production-media.paperswithcode.com)... 172.67.73.69, 104.26.13.155, 104.26.12.155, ...
# Connecting to production-media.paperswithcode.com (production-media.paperswithcode.com)|172.67.73.69|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 106477 (104K) [image/png]
# Saving to: ‘question.png’
#
# question.png        100%[===================>] 103.98K  --.-KB/s    in 0.07s
#
# 2023-07-09 20:45:56 (1.55 MB/s) - ‘question.png’ saved [106477/106477]

# %%
Image("question.png")

# %%
from transformers import AutoTokenizer, AutoModelForQuestionAnswering

tokenizer = AutoTokenizer.from_pretrained("mrm8488/bert-base-spanish-wwm-cased-finetuned-spa-squad2-es")
model = AutoModelForQuestionAnswering.from_pretrained("mrm8488/bert-base-spanish-wwm-cased-finetuned-spa-squad2-es")

question_answerer = pipeline("question-answering",  model = model, tokenizer = tokenizer)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/135 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/465 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/242k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/439M [00:00<?, ?B/s]

# %%
question_answerer(
    question="¿Dónde trabajo?",
    context="Me llamo Laura, tengo 33 años y trabajo en Madrid.",
)
# Out:
# {'score': 0.9127206206321716, 'start': 43, 'end': 49, 'answer': 'Madrid'}

# %%
question_answerer(
    question="¿Cuántos años tengo?",
    context="Me llamo Laura, tengo 33 años y trabajo en Madrid.",
)
# Out:
# {'score': 0.7957062125205994, 'start': 22, 'end': 24, 'answer': '33'}

# %%
question_answerer(
    question="¿Cómo me llamo?",
    context="Me llamo Laura, tengo 33 años y trabajo en Madrid.",
)
# Out:
# {'score': 0.9583200216293335, 'start': 9, 'end': 14, 'answer': 'Laura'}

# %% [markdown]
# ##Summarization

# %%
# !wget https://www.scrapehero.com/wp/wp-content/uploads/2021/05/Text-Summarization-NLP.jpg
# Out:
# --2023-07-09 20:46:13--  https://www.scrapehero.com/wp/wp-content/uploads/2021/05/Text-Summarization-NLP.jpg
# Resolving www.scrapehero.com (www.scrapehero.com)... 159.89.216.6
# Connecting to www.scrapehero.com (www.scrapehero.com)|159.89.216.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89290 (87K) [image/jpeg]
# Saving to: ‘Text-Summarization-NLP.jpg’
#
# Text-Summarization- 100%[===================>]  87.20K  --.-KB/s    in 0.06s
#
# 2023-07-09 20:46:13 (1.43 MB/s) - ‘Text-Summarization-NLP.jpg’ saved [89290/89290]

# %%
Image("Text-Summarization-NLP.jpg")

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("mrm8488/bert2bert_shared-spanish-finetuned-summarization")
model = AutoModelForSeq2SeqLM.from_pretrained("mrm8488/bert2bert_shared-spanish-finetuned-summarization")

summarizer = pipeline("summarization",  model = model, tokenizer = tokenizer, min_length=30, max_length=60)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/520 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/4.51k [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/242k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/555M [00:00<?, ?B/s]
# The following encoder weights were not tied to the decoder ['bert/pooler']
# Some weights of EncoderDecoderModel were not initialized from the model checkpoint at mrm8488/bert2bert_shared-spanish-finetuned-summarization and are newly initialized: ['decoder.bert.encoder.layer.9.attention.output.dense.bias', 'decoder.bert.encoder.layer.10.intermediate.dense.weight', 'decoder.bert.encoder.layer.9.attention.self.key.bias', 'decoder.bert.encoder.layer.2.attention.self.key.bias', 'decoder.bert.encoder.layer.11.intermediate.dense.weight', 'decoder.bert.encoder.layer.1.output.dense.bias', 'decoder.bert.encoder.layer.10.attention.self.key.bias', 'decoder.bert.encoder.layer.8.output.LayerNorm.bias', 'decoder.bert.encoder.layer.8.attention.output.dense.weight', 'decoder.bert.encoder.layer.8.output.LayerNorm.weight', 'decoder.bert.encoder.layer.3.attention.self.query.weight', 'decoder.bert.encoder.layer.7.attention.output.dense.bias', 'decoder.bert.encoder.layer.9.attention.self.value.bias', 'decoder.bert.encoder.layer.8.attention.self.key.bias', 'decoder.bert.encoder.layer.10.attention.self.key.weight', 'decoder.bert.encoder.layer.7.attention.output.dense.weight', 'decoder.bert.encoder.layer.8.attention.self.key.weight', 'decoder.bert.encoder.layer.7.attention.self.query.weight', 'decoder.bert.encoder.layer.5.attention.self.value.bias', 'decoder.bert.embeddings.position_embeddings.weight', 'decoder.bert.encoder.layer.6.attention.self.query.bias', 'decoder.bert.encoder.layer.4.output.LayerNorm.bias', 'decoder.bert.encoder.layer.2.output.dense.weight', 'decoder.bert.encoder.layer.9.attention.output.dense.weight', 'decoder.bert.encoder.layer.4.attention.self.key.bias', 'decoder.bert.encoder.layer.7.intermediate.dense.weight', 'decoder.bert.encoder.layer.6.output.dense.bias', 'decoder.bert.encoder.layer.6.intermediate.dense.weight', 'decoder.bert.encoder.layer.6.output.LayerNorm.bias', 'decoder.bert.encoder.layer.1.output.LayerNorm.bias', 'decoder.bert.encoder.layer.9.output.LayerNorm.bias', 'decoder.bert.encoder.layer.7.attention.output.LayerNorm.bias', 'decoder.bert.encoder.layer.6.attention.output.dense.weight', 'decoder.bert.encoder.layer.5.attention.output.LayerNorm.weight', 'decoder.bert.encoder.layer.5.intermediate.dense.weight', 'decoder.bert.encoder.layer.6.output.LayerNorm.weight', 'decoder.bert.encoder.layer.1.output.dense.weight', 'decoder.bert.encoder.layer.3.attention.output.LayerNorm.weight', 'decoder.bert.encoder.layer.5.attention.self.query.weight', 'decoder.bert.encoder.layer.4.attention.output.LayerNorm.weight', 'decoder.bert.encoder.layer.10.attention.output.dense.weight', 'decoder.bert.encoder.layer.7.attention.output.LayerNorm.weight', 'decoder.bert.embeddings.word_embeddings.weight', 'decoder.bert.encoder.layer.1.attention.self.value.weight', 'decoder.bert.encoder.layer.7.output.LayerNorm.bias', 'decoder.bert.encoder.layer.4.attention.self.query.bias', 'decoder.bert.encoder.layer.7.attention.self.value.weight', 'decoder.bert.encoder.layer.11.attention.output.dense.bias', 'decoder.bert.encoder.layer.3.attention.self.key.bias', 'decoder.bert.encoder.layer.8.attention.self.value.bias', 'decoder.bert.encoder.layer.8.output.dense.weight', 'decoder.bert.encoder.layer.2.output.LayerNorm.bias', 'decoder.bert.encoder.layer.3.output.LayerNorm.bias', 'decoder.bert.encoder.layer.8.attention.output.LayerNorm.bias', 'decoder.bert.encoder.layer.5.attention.self.query.bias', 'decoder.bert.encoder.layer.7.output.LayerNorm.weight', 'decoder.bert.encoder.layer.0.attention.self.value.bias', 'decoder.bert.encoder.layer.1.intermediate.dense.weight', 'decoder.bert.encoder.layer.10.output.dense.weight', 'decoder.bert.encoder.layer.5.output.LayerNorm.bias', 'decoder.bert.encoder.layer.2.attention.self.value.bias', 'decoder.bert.encoder.layer.4.attention.self.query.weight', 'decoder.bert.encoder.layer.2.output.LayerNorm.weight', 'decoder.bert.encoder.layer.10.attention.output.dense.bias', 'decoder.bert.encoder.layer.3.attention.self.key.weight', 'decoder.bert.encoder.layer.0.attention.output.LayerNorm.bias', 'decoder.be ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# The following encoder weights were not tied to the decoder ['bert/pooler']

# %%
from transformers import pipeline

summarizer(
    """
Todos los vagos del universo sabemos que una de las elaboraciones más socorridas cuando tienes invitados y
has prometido darles de comer o cenar es una tabla de embutidos y/o quesos (seguida muy de cerca por la fondue).
Quedas como un señor o señora con escaso esfuerzo, simplemente aprendiendo a combinar estos riquísimos alimentos;
cosa que en nuestro país -que no nos pese decirlo-, es bien sencillo, porque el producto de que disponemos es la pera y es difícil pifiarla.

Otro tema es que sea un producto que no conozcamos, y por eso pensemos que es una magnífica idea poner un cheddar o
un parmesano mediocre en una tabla en lugar del magnífico queso artesano del pueblo de al lado, del que no has tenido noticia en tu vida.
Espabila, alma de cántaro. De modo que no os vamos a sugerir que pongáis prosciutto del bueno en vuestra tabla,
aunque no tengamos nada contra él: este artículo va de usar producto nacional, que además de ser bueno y abundantísimo, es de proximidad.
"""
)
# Out:
# [{'summary_text': 'En nuestro país sabemos que una de las elaboraciones más socorridas cuando tienes invitados y has prometido darles de comer o cenar es una tabla de embutidos'}]

# %% [markdown]
# ##Translation

# %%
# !wget https://cdn.analyticsvidhya.com/wp-content/uploads/2019/01/enc_dec_simple.png
# Out:
# --2023-07-09 20:46:33--  https://cdn.analyticsvidhya.com/wp-content/uploads/2019/01/enc_dec_simple.png
# Resolving cdn.analyticsvidhya.com (cdn.analyticsvidhya.com)... 104.26.7.19, 104.26.6.19, 172.67.74.218, ...
# Connecting to cdn.analyticsvidhya.com (cdn.analyticsvidhya.com)|104.26.7.19|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19474 (19K) [image/png]
# Saving to: ‘enc_dec_simple.png’
#
# enc_dec_simple.png  100%[===================>]  19.02K  --.-KB/s    in 0s
#
# 2023-07-09 20:46:35 (109 MB/s) - ‘enc_dec_simple.png’ saved [19474/19474]

# %%
Image("enc_dec_simple.png")

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-es")
model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-en-es")
translator = pipeline("translation", model = model, tokenizer = tokenizer)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.47k [00:00<?, ?B/s]
# Downloading (…)olve/main/source.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# Downloading (…)olve/main/target.spm:   0%|          | 0.00/826k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.59M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/marian/tokenization_marian.py:194: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Downloading pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]

# %%
translator("I love going to the cinema and eating chocolate. Do you also like that?")
# Out:
# [{'translation_text': 'Me encanta ir al cine y comer chocolate. ¿También te gusta eso?'}]
